# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# cv2 is the stancdard library alias used for OpenCV in python
# we get all the major image processing from cv2
import cv2

# %%
img = cv2.imread("msd.jpeg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (593, 1080, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
cv2.imshow("msd",img)
#Wait indefenitely until a key is pressed 
# 0 means wait forever
# Without this, the windows will close immedidately
cv2.waitKey(10000)
# close all openCV windows
# important to release memory
cv2.destroyAllWindows()

# %%
# Convert image into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# while True:
#     cv2.imshow("Gray MSD", gray)
#     if cv2.waitKey(0)==5 :
#         break
# cv2.destroyAllWindows()

cv2.imshow("Gray MSD", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Pixel Manipulation
# ROI Region of Interest
# Drawing shapes and text
